# %%
import pandas as pd

col_names = [ 'c{0:02d}'.format(i) for i in range(2) ]

df = pd.read_csv("tweet.csv",sep='\t', names=col_names)

# %%
df
# Out:
#                                                      c00  c01
# 0      【PLAN】リノベーション・ルームのPLAN紹介です。間取り図と写真を載せていますのでご参照...  NaN
# 1      やれ町づくりだ、町おこしだ、リノベーションだとほざきながら、カフェかバーでも適当にやってみた...  NaN
# 2      【中古マン】春日部駅徒歩16分の格安売り中古マンション。60平米以上もあるのに480万円で販...  NaN
# 3      RT @ACPE_AutoCAD: 【 #OnlyOneAutoCAD ツールセット①：建築設計】  NaN
# 4      建築 #設計 の図面は、もちろんAutoCADにお任せください。壁・ドア・窓から、床・天井、...  NaN
# 5                                      【既存住宅（中古住宅）のメリット】  NaN
# 6                                          実際の住宅を見て検討できる  NaN
# 7                                                  #既存住宅  NaN
# 8                                                  #中古住宅  NaN
# 9                                                 #安心Ｒ住宅  NaN
# 10                                                #再建築不可  NaN
# 11                                              #リノベーション  NaN
# 12                            ＜施工実績＞#001 ～賃貸MSをリノベーション～   NaN
# 13                 バルコニー配置の洗濯機置場を洗面室に設置。水廻りにこだわった仕上がりです。  NaN
# ...

# %%
df['c01'].isnull().sum()
# Out:
# 17348
